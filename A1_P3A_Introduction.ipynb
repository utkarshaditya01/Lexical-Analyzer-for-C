# %% [markdown]
# <a href="https://colab.research.google.com/github/utkarshaditya01/Lexical-Analyzer-for-C/blob/master/A1_P3A_Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 1 Part 3A Introduction: Multi-label Image Classification

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ls
# Out:
# A1_P3A_Introduction.ipynb        voc_dataloader.py
# A1_P3B_Develop_Classifier.ipynb  VOCdevkit_2007/
# classifier.py                    voc_simple_classifier.pth
# download_data.sh                 VOCtest_06-Nov-2007.tar
# __pycache__/                     VOCtrainval_06-Nov-2007.tar

# %%
import os
os.chdir("gdrive/MyDrive/DL/Assignment1/assignment1-part3/")

# %%
# !bash download_data.sh
# Out:
# --2021-03-04 06:37:26--  http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 460032000 (439M) [application/x-tar]
# Saving to: ‘VOCtrainval_06-Nov-2007.tar’
#
# VOCtrainval_06-Nov- 100%[===================>] 438.72M  9.16MB/s    in 53s
#
# 2021-03-04 06:38:19 (8.34 MB/s) - ‘VOCtrainval_06-Nov-2007.tar’ saved [460032000/460032000]
#
# --2021-03-04 06:39:40--  http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtest_06-Nov-2007.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 451020800 (430M) [application/x-tar]
# Saving to: ‘VOCtest_06-Nov-2007.tar’
#
# VOCtest_06-Nov-2007 100%[===================>] 430.13M  9.15MB/s    in 49s
#
# 2021-03-04 06:40:30 (8.73 MB/s) - ‘VOCtest_06-Nov-2007.tar’ saved [451020800/451020800]

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torchvision

from torchvision import transforms
from sklearn.metrics import average_precision_score
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
from classifier import SimpleClassifier, Classifier#, AlexNet
from voc_dataloader import VocDataset, VOC_CLASSES

# %matplotlib inline
# %load_ext autoreload
#%reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # Multi-label Classification
# In this assignment, you train a classifier to do multi-label classificaton on the PASCAL VOC 2007 dataset. The dataset has 20 different class which can appear in any given image. Your classifier will predict whether each class appears in an image. This task is slightly different from exclusive multiclass classification like the ImageNet competition where only a single most appropriate class is predicted for an image.
#
# ## Part 3A
# You will use this notebook to warm up with pytorch.
#
# ### What to do
# In part 3A, You are asked to run below experiments. You don't need to change hyperparameters for this Part 3A's experiments. (the following code provides everything that you will need.)
# 1. to train a simple network (defined in ```classifiers.py```)
# 2. to train the AlexNet (PyTorch built-in)
#     - from scratch
#     - finetuning AlexNet pretrained on ImageNet
#
#
#
# ### What to submit
# We ask you to run the following code and report the results in your homework submission. You may want to leverage this part 3A get yourself familiar with PyTorch.
#
# You will the need the numbers and plots this notebook outputs for reports, but you are not required to submit this notebook as a printed pdf.

# %% [markdown]
# ## Reading Pascal Data

# %% [markdown]
# ### Loading Training Data

# %% [markdown]
# In the following cell we will load the training data and also apply some transforms to the data.

# %%
# Transforms applied to the training data
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std= [0.229, 0.224, 0.225])

train_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize
        ])

# %%
ds_train = VocDataset('VOCdevkit_2007/VOC2007/','train',train_transform)
# Out:
# 100%|██████████| 2501/2501 [09:52<00:00,  4.22it/s]
# /content/gdrive/My Drive/DL/Assignment1/assignment1-part3/voc_dataloader.py:109: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(names), np.array(labels).astype(np.float32), np.array(box_indices), label_order

# %% [markdown]
# ### Loading Validation Data

# %% [markdown]
# We will load the test data for the PASCAL VOC 2007 dataset. Do __NOT__ add data augmentation transforms to validation data.

# %%
# Transforms applied to the testing data
test_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize,
        ])

# %%
ds_val = VocDataset('VOCdevkit_2007/VOC2007/','val',test_transform)
# Out:
# 100%|██████████| 2510/2510 [09:01<00:00,  4.63it/s]
# /content/gdrive/My Drive/DL/Assignment1/assignment1-part3/voc_dataloader.py:109: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(names), np.array(labels).astype(np.float32), np.array(box_indices), label_order

# %% [markdown]
# ### Visualizing the Data
#
# PASCAL VOC has bounding box annotations in addition to class labels. Use the following code to visualize some random examples and corresponding annotations from the train set.

# %%
for i in range(5):
    idx = np.random.randint(0, len(ds_train.names)+1)
    _imgpath = os.path.join('VOCdevkit_2007/VOC2007/', 'JPEGImages', ds_train.names[idx]+'.jpg')
    img = Image.open(_imgpath).convert('RGB')
    draw = ImageDraw.Draw(img)
    for j in range(len(ds_train.box_indices[idx])):
        obj = ds_train.box_indices[idx][j]
        draw.rectangle(list(obj), outline=(255,0,0))
        draw.text(list(obj[0:2]), ds_train.classes[ds_train.label_order[idx][j]], fill=(0,255,0))
    plt.figure(figsize = (10,10))
    plt.imshow(np.array(img))

# %% [markdown]
# # Classification

# %%
# declare what device to use: gpu/cpu
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
train_loader = torch.utils.data.DataLoader(dataset=ds_train,
                                               batch_size=50, 
                                               shuffle=True,
                                               num_workers=1)

# %%
val_loader = torch.utils.data.DataLoader(dataset=ds_val,
                                               batch_size=50, 
                                               shuffle=True,
                                               num_workers=1)

# %%
def train_classifier(train_loader, classifier, criterion, optimizer):
    classifier.train()
    loss_ = 0.0
    losses = []
    for i, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        logits = classifier(images)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        losses.append(loss)
    return torch.stack(losses).mean().item()

# %%
def test_classifier(test_loader, classifier, criterion, print_ind_classes=True, print_total=True):
    classifier.eval()
    losses = []
    with torch.no_grad():
        y_true = np.zeros((0,21))
        y_score = np.zeros((0,21))
        for i, (images, labels) in enumerate(test_loader):
            images, labels = images.to(device), labels.to(device)
            logits = classifier(images)
            y_true = np.concatenate((y_true, labels.cpu().numpy()), axis=0)
            y_score = np.concatenate((y_score, logits.cpu().numpy()), axis=0)
            loss = criterion(logits, labels)
            losses.append(loss.item())
        aps = []
        # ignore first class which is background
        for i in range(1, y_true.shape[1]):
            ap = average_precision_score(y_true[:, i], y_score[:, i])
            if print_ind_classes:
                print('-------  Class: {:<12}     AP: {:>8.4f}  -------'.format(VOC_CLASSES[i], ap))
            aps.append(ap)
        
        mAP = np.mean(aps)
        test_loss = np.mean(losses)
        if print_total:
            print('mAP: {0:.4f}'.format(mAP))
            print('Avg loss: {}'.format(test_loss))
        
    return mAP, test_loss, aps

# %%
# plot functions
def plot_losses(train, val, test_frequency, num_epochs):
    plt.plot(train, label="train")
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, val, label="val")
    plt.title("Loss Plot")
    plt.ylabel("Loss")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()
    
def plot_mAP(train, val, test_frequency, num_epochs):
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, train, label="train")
    plt.plot(indices, val, label="val")
    plt.title("mAP Plot")
    plt.ylabel("mAP")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()

# %% [markdown]
# ## Training the network
#
# The simple network you are given as is will allow you to reach around 0.15-0.2 mAP. In this project, you will find ways to design a better network. Save plots and final test mAP scores as you will be adding these to the writeup.

# %%
def train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency=5):
    train_losses = []
    train_mAPs = []
    val_losses = []
    val_mAPs = []

    for epoch in range(1,num_epochs+1):
        print("Starting epoch number " + str(epoch))
        train_loss = train_classifier(train_loader, classifier, criterion, optimizer)
        train_losses.append(train_loss)
        print("Loss for Training on Epoch " +str(epoch) + " is "+ str(train_loss))
        if(epoch%test_frequency==0 or epoch==1):
            mAP_train, _, _ = test_classifier(train_loader, classifier, criterion, False, False)
            train_mAPs.append(mAP_train)
            mAP_val, val_loss, _ = test_classifier(val_loader, classifier, criterion)
            print('Evaluating classifier')
            print("Mean Precision Score for Testing on Epoch " +str(epoch) + " is "+ str(mAP_val))
            val_losses.append(val_loss)
            val_mAPs.append(mAP_val)
    
    return classifier, train_losses, val_losses, train_mAPs, val_mAPs

# %%
classifier = SimpleClassifier().to(device)
# You can can use this function to reload a network you have already saved previously
#classifier.load_state_dict(torch.load('voc_classifier.pth'))

# %%
criterion = nn.MultiLabelSoftMarginLoss()
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)

# %%
# Training the Classifier
num_epochs = 20
test_frequency = 5

classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.4907152056694031
# -------  Class: aeroplane        AP:   0.1054  -------
# -------  Class: bicycle          AP:   0.0481  -------
# -------  Class: bird             AP:   0.1197  -------
# -------  Class: boat             AP:   0.0907  -------
# -------  Class: bottle           AP:   0.0418  -------
# -------  Class: bus              AP:   0.0291  -------
# -------  Class: car              AP:   0.1120  -------
# -------  Class: cat              AP:   0.0845  -------
# -------  Class: chair            AP:   0.1194  -------
# -------  Class: cow              AP:   0.0315  -------
# -------  Class: diningtable      AP:   0.0527  -------
# -------  Class: dog              AP:   0.1188  -------
# -------  Class: horse            AP:   0.0530  -------
# -------  Class: motorbike        AP:   0.0460  -------
# -------  Class: person           AP:   0.3517  -------
# -------  Class: pottedplant      AP:   0.0468  -------
# -------  Class: sheep            AP:   0.0277  -------
# -------  Class: sofa             AP:   0.0907  -------
# -------  Class: train            AP:   0.0357  -------
# -------  Class: tvmonitor        AP:   0.0502  -------
# mAP: 0.0828
# Avg loss: 0.24329676522928126
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.08277003070682906
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.2483585625886917
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.24330656230449677
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.24131743609905243
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.23967710137367249
# -------  Class: aeroplane        AP:   0.0875  -------
# -------  Class: bicycle          AP:   0.0456  -------
# -------  Class: bird             AP:   0.1199  -------
# -------  Class: boat             AP:   0.0826  -------
# -------  Class: bottle           AP:   0.0441  -------
# -------  Class: bus              AP:   0.0297  -------
# -------  Class: car              AP:   0.1167  -------
# -------  Class: cat              AP:   0.1026  -------
# -------  Class: chair            AP:   0.1309  -------
# -------  Class: cow              AP:   0.0332  -------
# -------  Class: diningtable      AP:   0.0542  -------
# -------  Class: dog              AP:   0.1283  -------
# -------  Class: horse            AP:   0.0530  -------
# -------  Class: motorbike        AP:   0.0426  -------
# -------  Class: person           AP:   0.3963  -------
# -------  Class: pottedplant      AP:   0.0469  -------
# -------  Class: sheep            AP:   0.0324  -------
# -------  Class: sofa             AP:   0.1041  -------
# -------  Class: train            AP:   0.0395  -------
# -------  Class: tvmonitor        AP:   0.0527  -------
# mAP: 0.0871
# Avg loss: 0.23626719385969872
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.0871270983096197
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.241436168551445
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.23913291096687317
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.23507298529148102
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.23368914425373077
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.2312154620885849
# -------  Class: aeroplane        AP:   0.2096  -------
# -------  Class: bicycle          AP:   0.0525  -------
# -------  Class: bird             AP:   0.1083  -------
# -------  Class: boat             AP:   0.1615  -------
# -------  Class: bottle           AP:   0.0590  -------
# -------  Class: bus              AP:   0.0504  -------
# -------  Class: car              AP:   0.1577  -------
# -------  Class: cat              AP:   0.1274  -------
# -------  Class: chair            AP:   0.1650  -------
# -------  Class: cow              AP:   0.0345  -------
# -------  Class: diningtable      AP:   0.0765  -------
# -------  Class: dog              AP:   0.1381  -------
# -------  Class: horse            AP:   0.0639  -------
# -------  Class: motorbike        AP:   0.0450  -------
# -------  Class: person           AP:   0.4815  -------
# -------  Class: pottedplant      AP:   0.0527  -------
# -------  Class: sheep            AP:   0.0329  -------
# -------  Class: sofa             AP:   0.1322  -------
# -------  Class: train            AP:   0.0949  -------
# -------  Class: tvmonitor        AP:   0.0630  -------
# mAP: 0.1153
# Avg loss: 0.2299145065686282
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.11532416559745284
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.2295324057340622
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.22893476486206055
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.22797410190105438
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.22279758751392365
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.22653992474079132
# -------  Class: aeroplane        AP:   0.3421  -------
# -------  Class: bicycle          AP:   0.0650  -------
# -------  Class: bird             AP:   0.0953  -------
# -------  Class: boat             AP:   0.2178  -------
# -------  Class: bottle           AP:   0.0695  -------
# -------  Class: bus              AP:   0.0690  -------
# -------  Class: car              AP:   0.1760  -------
# -------  Class: cat              AP:   0.1352  -------
# -------  Class: chair            AP:   0.1996  -------
# -------  Class: cow              AP:   0.0348  -------
# -------  Class: diningtable      AP:   0.1196  -------
# -------  Class: dog              AP:   0.1557  -------
# -------  Class: horse            AP:   0.0983  -------
# -------  Class: motorbike        AP:   0.0522  -------
# -------  Class: person           AP:   0.4911  -------
# -------  Class: pottedplant      AP:   0.0645  -------
# -------  Class: sheep            AP:   0.0401  -------
# -------  Class: sofa             AP:   0.1624  -------
# -------  Class: train            AP:   0.1327  -------
# -------  Class: tvmonitor        AP:   0.0850  -------
# mAP: 0.1403
# Avg loss: 0.22442733569472445
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.14029431760969338
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.22559799253940582
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.2258729636669159
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.21869026124477386
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.21916437149047852
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.2170865535736084
# -------  Class: aeroplane        AP:   0.3664  -------
# -------  Class: bicycle          AP:   0.0767  -------
# -------  Class: bird             AP:   0.1076  -------
# -------  Class: boat             AP:   0.2270  -------
# -------  Class: bottle           AP:   0.0789  -------
# -------  Class: bus              AP:   0.0753  -------
# -------  Class: car              AP:   0.2227  -------
# -------  Class: cat              AP:   0.1408  -------
# -------  Class: chair            AP:   0.2301  -------
# -------  Class: cow              AP:   0.0382  -------
# -------  Class: diningtable      AP:   0.1598  -------
# -------  Class: dog              AP:   0.1491  -------
# -------  Class: horse            AP:   0.1290  -------
# -------  Class: motorbike        AP:   0.0636  -------
# -------  Class: person           AP:   0.4933  -------
# -------  Class: pottedplant      AP:   0.0761  -------
# -------  Class: sheep            AP:   0.0551  -------
# -------  Class: sofa             AP:   0.1670  -------
# -------  Class: train            AP:   0.1543  -------
# -------  Class: tvmonitor        AP:   0.1084  -------
# mAP: 0.1560
# Avg loss: 0.22196310349539214
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.15597873458764033

# %%
# Compare train and validation metrics
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
# Save the clssifier network
# Suggestion: you can save checkpoints of your network during training and reload them later
torch.save(classifier.state_dict(), './voc_simple_classifier.pth')

# %% [markdown]
# # Evaluate on test set

# %%
ds_test = VocDataset('VOCdevkit_2007/VOC2007test/','test', test_transform)

test_loader = torch.utils.data.DataLoader(dataset=ds_test,
                                               batch_size=50, 
                                               shuffle=False,
                                               num_workers=1)

# Transforms applied to the testing data
test_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize,
        ])

mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)

# %% [markdown]
# # AlexNet Baselines (From Scratch)

# %% [markdown]
# AlexNet was one of the earliest deep learning models to have success in classification. In this section we will be running classification with AlexNet as a baseline. Furthermore, we will run an ImageNet-pretrained AlexNet to observe the impact of well-trained features. Save plots and final test mAP scores as you will be adding these to the writeup.

# %% [markdown]
# ## Running AlexNet
#
# In this section, we train AlexNet from scratch using the same hyperparameters as our previous experiment.

# %%
num_epochs = 20
test_frequency = 5

# Change classifier to AlexNet
classifier = torchvision.models.alexnet(pretrained=False)
classifier.classifier._modules['6'] = nn.Linear(4096, 21)   
classifier = classifier.to(device)

criterion = nn.MultiLabelSoftMarginLoss()

optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)

# %%
classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.5555909872055054
# -------  Class: aeroplane        AP:   0.0979  -------
# -------  Class: bicycle          AP:   0.0429  -------
# -------  Class: bird             AP:   0.1022  -------
# -------  Class: boat             AP:   0.1010  -------
# -------  Class: bottle           AP:   0.0431  -------
# -------  Class: bus              AP:   0.0282  -------
# -------  Class: car              AP:   0.1104  -------
# -------  Class: cat              AP:   0.0982  -------
# -------  Class: chair            AP:   0.1168  -------
# -------  Class: cow              AP:   0.0340  -------
# -------  Class: diningtable      AP:   0.0525  -------
# -------  Class: dog              AP:   0.1164  -------
# -------  Class: horse            AP:   0.0464  -------
# -------  Class: motorbike        AP:   0.0362  -------
# -------  Class: person           AP:   0.3477  -------
# -------  Class: pottedplant      AP:   0.0426  -------
# -------  Class: sheep            AP:   0.0383  -------
# -------  Class: sofa             AP:   0.0984  -------
# -------  Class: train            AP:   0.0394  -------
# -------  Class: tvmonitor        AP:   0.0478  -------
# mAP: 0.0820
# Avg loss: 0.3133419144387339
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.08201932294635608
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.2534911632537842
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.24451574683189392
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.24748218059539795
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.24286840856075287
# -------  Class: aeroplane        AP:   0.0983  -------
# -------  Class: bicycle          AP:   0.0475  -------
# -------  Class: bird             AP:   0.1138  -------
# -------  Class: boat             AP:   0.1084  -------
# -------  Class: bottle           AP:   0.0420  -------
# -------  Class: bus              AP:   0.0298  -------
# -------  Class: car              AP:   0.1141  -------
# -------  Class: cat              AP:   0.0892  -------
# -------  Class: chair            AP:   0.1193  -------
# -------  Class: cow              AP:   0.0350  -------
# -------  Class: diningtable      AP:   0.0532  -------
# -------  Class: dog              AP:   0.1160  -------
# -------  Class: horse            AP:   0.0487  -------
# -------  Class: motorbike        AP:   0.0379  -------
# -------  Class: person           AP:   0.4703  -------
# -------  Class: pottedplant      AP:   0.0453  -------
# -------  Class: sheep            AP:   0.0378  -------
# -------  Class: sofa             AP:   0.0951  -------
# -------  Class: train            AP:   0.0407  -------
# -------  Class: tvmonitor        AP:   0.0483  -------
# mAP: 0.0895
# Avg loss: 0.24036700556091234
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.08953376148625622
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.24299143254756927
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.23972231149673462
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.2419678270816803
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.24105986952781677
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.24050231277942657
# -------  Class: aeroplane        AP:   0.0806  -------
# -------  Class: bicycle          AP:   0.0495  -------
# -------  Class: bird             AP:   0.1215  -------
# -------  Class: boat             AP:   0.0900  -------
# -------  Class: bottle           AP:   0.0433  -------
# -------  Class: bus              AP:   0.0302  -------
# -------  Class: car              AP:   0.1239  -------
# -------  Class: cat              AP:   0.0910  -------
# -------  Class: chair            AP:   0.1274  -------
# -------  Class: cow              AP:   0.0358  -------
# -------  Class: diningtable      AP:   0.0570  -------
# -------  Class: dog              AP:   0.1213  -------
# -------  Class: horse            AP:   0.0513  -------
# -------  Class: motorbike        AP:   0.0401  -------
# -------  Class: person           AP:   0.4545  -------
# -------  Class: pottedplant      AP:   0.0484  -------
# -------  Class: sheep            AP:   0.0454  -------
# -------  Class: sofa             AP:   0.0974  -------
# -------  Class: train            AP:   0.0420  -------
# -------  Class: tvmonitor        AP:   0.0499  -------
# mAP: 0.0900
# Avg loss: 0.23781485680271597
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.09001801543109406
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.2408161759376526
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.239691823720932
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.23997971415519714
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.23894594609737396
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.24487335979938507
# -------  Class: aeroplane        AP:   0.0725  -------
# -------  Class: bicycle          AP:   0.0522  -------
# -------  Class: bird             AP:   0.1255  -------
# -------  Class: boat             AP:   0.0745  -------
# -------  Class: bottle           AP:   0.0476  -------
# -------  Class: bus              AP:   0.0315  -------
# -------  Class: car              AP:   0.1419  -------
# -------  Class: cat              AP:   0.0952  -------
# -------  Class: chair            AP:   0.1469  -------
# -------  Class: cow              AP:   0.0369  -------
# -------  Class: diningtable      AP:   0.0671  -------
# -------  Class: dog              AP:   0.1236  -------
# -------  Class: horse            AP:   0.0548  -------
# -------  Class: motorbike        AP:   0.0440  -------
# -------  Class: person           AP:   0.4683  -------
# -------  Class: pottedplant      AP:   0.0540  -------
# -------  Class: sheep            AP:   0.0476  -------
# -------  Class: sofa             AP:   0.1014  -------
# -------  Class: train            AP:   0.0468  -------
# -------  Class: tvmonitor        AP:   0.0520  -------
# mAP: 0.0942
# Avg loss: 0.24514165286924325
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.09422712026250953
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.24036280810832977
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.23706302046775818
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.23935386538505554
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.23752351105213165
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.2310338169336319
# -------  Class: aeroplane        AP:   0.1961  -------
# -------  Class: bicycle          AP:   0.0625  -------
# -------  Class: bird             AP:   0.1258  -------
# -------  Class: boat             AP:   0.1547  -------
# -------  Class: bottle           AP:   0.0612  -------
# -------  Class: bus              AP:   0.0483  -------
# -------  Class: car              AP:   0.1821  -------
# -------  Class: cat              AP:   0.1042  -------
# -------  Class: chair            AP:   0.1703  -------
# -------  Class: cow              AP:   0.0397  -------
# -------  Class: diningtable      AP:   0.0859  -------
# -------  Class: dog              AP:   0.1317  -------
# -------  Class: horse            AP:   0.0571  -------
# -------  Class: motorbike        AP:   0.0460  -------
# -------  Class: person           AP:   0.4972  -------
# -------  Class: pottedplant      AP:   0.0618  -------
# -------  Class: sheep            AP:   0.0452  -------
# -------  Class: sofa             AP:   0.1165  -------
# -------  Class: train            AP:   0.0819  -------
# -------  Class: tvmonitor        AP:   0.0526  -------
# mAP: 0.1160
# Avg loss: 0.2302795011623233
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.11603974455957507

# %%
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
print("Test mAP: ", mAP_test)
# Out:
# -------  Class: aeroplane        AP:   0.1586  -------
# -------  Class: bicycle          AP:   0.0580  -------
# -------  Class: bird             AP:   0.0995  -------
# -------  Class: boat             AP:   0.1219  -------
# -------  Class: bottle           AP:   0.0590  -------
# -------  Class: bus              AP:   0.0431  -------
# -------  Class: car              AP:   0.1776  -------
# -------  Class: cat              AP:   0.1062  -------
# -------  Class: chair            AP:   0.1550  -------
# -------  Class: cow              AP:   0.0467  -------
# -------  Class: diningtable      AP:   0.0683  -------
# -------  Class: dog              AP:   0.1360  -------
# -------  Class: horse            AP:   0.0550  -------
# -------  Class: motorbike        AP:   0.0421  -------
# -------  Class: person           AP:   0.5033  -------
# -------  Class: pottedplant      AP:   0.0529  -------
# -------  Class: sheep            AP:   0.0612  -------
# -------  Class: sofa             AP:   0.1178  -------
# -------  Class: train            AP:   0.0968  -------
# -------  Class: tvmonitor        AP:   0.0546  -------
# mAP: 0.1107
# Avg loss: 0.22693380668759347
# Test mAP:  0.1106832434381824

# %% [markdown]
# You should notice somewhat poor performance. You could try running AlexNet with an Adam optimizer instead with learning rate 1e-4 to see if that makes a difference. This experiment is not required for the writeup, but it may show you the importance of a good learning rate and optimizer.

# %% [markdown]
# ## Pretrained AlexNet

# %% [markdown]
# Here we look at the impact of pretrained features. This model's weights were trained on ImageNet, which is a much larger dataset. How do pretrained features perform on VOC? Why do you think there is such a large difference in performance?

# %%
num_epochs = 20
test_frequency = 5

# Load Pretrained AlexNet
classifier = torchvision.models.alexnet(pretrained=True)
classifier.classifier._modules['6'] = nn.Linear(4096, 21)   
classifier = classifier.to(device)
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-4df8aa71.pth
# HBox(children=(FloatProgress(value=0.0, max=244418560.0), HTML(value='')))

# %%
classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.22209228575229645
# -------  Class: aeroplane        AP:   0.7340  -------
# -------  Class: bicycle          AP:   0.5896  -------
# -------  Class: bird             AP:   0.8104  -------
# -------  Class: boat             AP:   0.6677  -------
# -------  Class: bottle           AP:   0.2446  -------
# -------  Class: bus              AP:   0.4394  -------
# -------  Class: car              AP:   0.7500  -------
# -------  Class: cat              AP:   0.7220  -------
# -------  Class: chair            AP:   0.5951  -------
# -------  Class: cow              AP:   0.2567  -------
# -------  Class: diningtable      AP:   0.4756  -------
# -------  Class: dog              AP:   0.5963  -------
# -------  Class: horse            AP:   0.6390  -------
# -------  Class: motorbike        AP:   0.6470  -------
# -------  Class: person           AP:   0.9022  -------
# -------  Class: pottedplant      AP:   0.3576  -------
# -------  Class: sheep            AP:   0.3515  -------
# -------  Class: sofa             AP:   0.4654  -------
# -------  Class: train            AP:   0.7480  -------
# -------  Class: tvmonitor        AP:   0.4893  -------
# mAP: 0.5741
# Avg loss: 0.1387869287647453
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.5740834201501003
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.12029901891946793
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.10588691383600235
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.09770899266004562
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.10098831355571747
# -------  Class: aeroplane        AP:   0.8368  -------
# -------  Class: bicycle          AP:   0.7161  -------
# -------  Class: bird             AP:   0.8593  -------
# -------  Class: boat             AP:   0.7602  -------
# -------  Class: bottle           AP:   0.3702  -------
# -------  Class: bus              AP:   0.5861  -------
# -------  Class: car              AP:   0.8064  -------
# -------  Class: cat              AP:   0.7984  -------
# -------  Class: chair            AP:   0.6231  -------
# -------  Class: cow              AP:   0.4374  -------
# -------  Class: diningtable      AP:   0.5527  -------
# -------  Class: dog              AP:   0.6744  -------
# -------  Class: horse            AP:   0.7293  -------
# -------  Class: motorbike        AP:   0.7683  -------
# -------  Class: person           AP:   0.9008  -------
# -------  Class: pottedplant      AP:   0.4456  -------
# -------  Class: sheep            AP:   0.6200  -------
# -------  Class: sofa             AP:   0.5502  -------
# -------  Class: train            AP:   0.8889  -------
# -------  Class: tvmonitor        AP:   0.6591  -------
# mAP: 0.6792
# Avg loss: 0.12121223629105325
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.6791725461160844
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.07953131943941116
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.08306949585676193
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.08981357514858246
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.0694211795926094
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.05276457592844963
# -------  Class: aeroplane        AP:   0.8595  -------
# -------  Class: bicycle          AP:   0.7217  -------
# -------  Class: bird             AP:   0.8561  -------
# -------  Class: boat             AP:   0.7664  -------
# -------  Class: bottle           AP:   0.3439  -------
# -------  Class: bus              AP:   0.5951  -------
# -------  Class: car              AP:   0.8184  -------
# -------  Class: cat              AP:   0.7849  -------
# -------  Class: chair            AP:   0.6185  -------
# -------  Class: cow              AP:   0.5452  -------
# -------  Class: diningtable      AP:   0.5673  -------
# -------  Class: dog              AP:   0.6787  -------
# -------  Class: horse            AP:   0.7578  -------
# -------  Class: motorbike        AP:   0.7853  -------
# -------  Class: person           AP:   0.9005  -------
# -------  Class: pottedplant      AP:   0.4594  -------
# -------  Class: sheep            AP:   0.6260  -------
# -------  Class: sofa             AP:   0.5344  -------
# -------  Class: train            AP:   0.8869  -------
# -------  Class: tvmonitor        AP:   0.6570  -------
# mAP: 0.6881
# Avg loss: 0.12896740042111454
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.6881496885025988
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.04486013203859329
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.04066954553127289
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.049136873334646225
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.033315666019916534
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.031047025695443153
# -------  Class: aeroplane        AP:   0.8558  -------
# -------  Class: bicycle          AP:   0.7228  -------
# -------  Class: bird             AP:   0.8569  -------
# -------  Class: boat             AP:   0.7425  -------
# -------  Class: bottle           AP:   0.3199  -------
# -------  Class: bus              AP:   0.5612  -------
# -------  Class: car              AP:   0.8121  -------
# -------  Class: cat              AP:   0.7889  -------
# -------  Class: chair            AP:   0.6225  -------
# -------  Class: cow              AP:   0.5585  -------
# -------  Class: diningtable      AP:   0.5480  -------
# -------  Class: dog              AP:   0.6966  -------
# -------  Class: horse            AP:   0.7580  -------
# -------  Class: motorbike        AP:   0.7878  -------
# -------  Class: person           AP:   0.8975  -------
# -------  Class: pottedplant      AP:   0.4363  -------
# -------  Class: sheep            AP:   0.6064  -------
# -------  Class: sofa             AP:   0.5262  -------
# -------  Class: train            AP:   0.8893  -------
# -------  Class: tvmonitor        AP:   0.6300  -------
# mAP: 0.6809
# Avg loss: 0.15453911075989404
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.6808610985623857
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.02430366352200508
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.02031545527279377
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.024877339601516724
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.020501507446169853
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.015375612303614616
# -------  Class: aeroplane        AP:   0.8438  -------
# -------  Class: bicycle          AP:   0.7045  -------
# -------  Class: bird             AP:   0.8544  -------
# -------  Class: boat             AP:   0.7277  -------
# -------  Class: bottle           AP:   0.2904  -------
# -------  Class: bus              AP:   0.6019  -------
# -------  Class: car              AP:   0.8122  -------
# -------  Class: cat              AP:   0.7886  -------
# -------  Class: chair            AP:   0.6070  -------
# -------  Class: cow              AP:   0.5300  -------
# -------  Class: diningtable      AP:   0.5649  -------
# -------  Class: dog              AP:   0.6853  -------
# -------  Class: horse            AP:   0.7551  -------
# -------  Class: motorbike        AP:   0.7810  -------
# -------  Class: person           AP:   0.8927  -------
# -------  Class: pottedplant      AP:   0.4485  -------
# -------  Class: sheep            AP:   0.5823  -------
# -------  Class: sofa             AP:   0.4908  -------
# -------  Class: train            AP:   0.8765  -------
# -------  Class: tvmonitor        AP:   0.6463  -------
# mAP: 0.6742
# Avg loss: 0.18516765870884352
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.6741927571530966

# %%
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
print("Test mAP: ", mAP_test)
# Out:
# -------  Class: aeroplane        AP:   0.8498  -------
# -------  Class: bicycle          AP:   0.7597  -------
# -------  Class: bird             AP:   0.8133  -------
# -------  Class: boat             AP:   0.7877  -------
# -------  Class: bottle           AP:   0.2889  -------
# -------  Class: bus              AP:   0.6808  -------
# -------  Class: car              AP:   0.8310  -------
# -------  Class: cat              AP:   0.7610  -------
# -------  Class: chair            AP:   0.5704  -------
# -------  Class: cow              AP:   0.5118  -------
# -------  Class: diningtable      AP:   0.5809  -------
# -------  Class: dog              AP:   0.6975  -------
# -------  Class: horse            AP:   0.8220  -------
# -------  Class: motorbike        AP:   0.7506  -------
# -------  Class: person           AP:   0.9117  -------
# -------  Class: pottedplant      AP:   0.4732  -------
# -------  Class: sheep            AP:   0.5974  -------
# -------  Class: sofa             AP:   0.5015  -------
# -------  Class: train            AP:   0.8650  -------
# -------  Class: tvmonitor        AP:   0.6201  -------
# mAP: 0.6837
# Avg loss: 0.17596201941370965
# Test mAP:  0.6837035048695312
